# %%
#TASK 5 SALES PREDECTION USING PYTHON

#Import modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Reading the dataset
df=pd.read_csv('/Users/mallikharjunaakula/Downloads/Advertising.csv')
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
#Data cleaning and Analysis
data=df.drop(labels=["Unnamed: 0"],axis=1)
data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
df.shape
# Out:
# (200, 5)

# %%
df.isnull()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0         False  False  False      False  False
# 1         False  False  False      False  False
# 2         False  False  False      False  False
# 3         False  False  False      False  False
# 4         False  False  False      False  False
# ..          ...    ...    ...        ...    ...
# 195       False  False  False      False  False
# 196       False  False  False      False  False
# 197       False  False  False      False  False
# 198       False  False  False      False  False
# 199       False  False  False      False  False
#
# [200 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
x=df.iloc[:, 0:-1]
x
# Out:
#      Unnamed: 0     TV  Radio  Newspaper
# 0             1  230.1   37.8       69.2
# 1             2   44.5   39.3       45.1
# 2             3   17.2   45.9       69.3
# 3             4  151.5   41.3       58.5
# 4             5  180.8   10.8       58.4
# ..          ...    ...    ...        ...
# 195         196   38.2    3.7       13.8
# 196         197   94.2    4.9        8.1
# 197         198  177.0    9.3        6.4
# 198         199  283.6   42.0       66.2
# 199         200  232.1    8.6        8.7
#
# [200 rows x 4 columns]

# %%
y=df.iloc[:,-1]
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
#VISUALIZING THE DATA


plt.plot(x,y,ls='',marker='o')
plt.xlabel('Adverstising')
plt.ylabel('Sales')
plt.legend(['TV','Radio','Newspaper'])
plt.title('Sales Percentage')
# Out:
# Text(0.5, 1.0, 'Sales Percentage')

# %%
#TRAIN THE DATA.

from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=40)

# %%
x_train
# Out:
#      Unnamed: 0     TV  Radio  Newspaper
# 188         189  286.0   13.9        3.7
# 170         171   50.0   11.6       18.4
# 107         108   90.4    0.3       23.2
# 65           66   69.0    9.3        0.9
# 109         110  255.4   26.9        5.5
# ..          ...    ...    ...        ...
# 50           51  199.8    3.1       34.6
# 184         185  253.8   21.3       30.0
# 165         166  234.5    3.4       84.8
# 7             8  120.2   19.6       11.6
# 70           71  199.1   30.6       38.7
#
# [140 rows x 4 columns]

# %%
x_test
# Out:
#      Unnamed: 0     TV  Radio  Newspaper
# 96           97  197.6    3.5        5.9
# 5             6    8.7   48.9       75.0
# 116         117  139.2   14.3       25.6
# 35           36  290.7    4.1        8.5
# 183         184  287.6   43.0       71.8
# 160         161  172.5   18.1       30.7
# 54           55  262.7   28.8       15.9
# 134         135   36.9   38.6       65.6
# 90           91  134.3    4.9        9.3
# 191         192   75.5   10.8        6.0
# 139         140  184.9   43.9        1.7
# 142         143  220.5   33.2       37.9
# 177         178  170.2    7.8       35.2
# 26           27  142.9   29.3       12.6
# 89           90  109.8   47.8       51.4
# 140         141   73.4   17.0       12.9
# 171         172  164.5   20.9       47.4
# 23           24  228.3   16.9       26.2
# 132         133    8.4   27.2        2.1
# 37           38   74.7   49.4       45.7
# 151         152  121.0    8.4       48.7
# 28           29  248.8   27.1       22.9
# ...

# %%
y_train
# Out:
# 188    15.9
# 170     8.4
# 107     8.7
# 65      9.3
# 109    19.8
#        ...
# 50     11.4
# 184    17.6
# 165    11.9
# 7      13.2
# 70     18.3
# Name: Sales, Length: 140, dtype: float64

# %%
y_test
# Out:
# 96     11.7
# 5       7.2
# 116    12.2
# 35     12.8
# 183    26.2
# 160    14.4
# 54     20.2
# 134    10.8
# 90     11.2
# 191     9.9
# 139    20.7
# 142    20.1
# 177    11.7
# 26     15.0
# 89     16.7
# 140    10.9
# 171    14.5
# 23     15.5
# 132     5.7
# 37     14.7
# 151    11.6
# 28     18.9
# 85     15.2
# 93     22.2
# 174    11.5
# 75      8.7
# 18     11.3
# 105    19.2
# 121     7.0
# 130     1.6
# 33     17.4
# 46     10.6
# 168    17.1
# 169    15.0
# 11     17.4
# 166     8.0
# 81     12.3
# 111    21.8
# 67     13.4
# 147    25.4
# 86     12.0
# 182     8.7
# 69     22.3
# 125    10.6
# 42     20.7
# 77     14.2
# 62     15.7
# 154    15.6
# 59     18.4
# 148    10.9
# 175    27.0
# 24      9.7
# 143    10.4
# 64     18.0
# 196     9.7
# 40     16.6
# 112    14.1
# 52     22.6
# 145    10.3
# 136     9.5
# Name: Sales, dtype: float64

# %%
x_train=x_train.astype(int)
y_train=y_train.astype(int)
x_test=x_test.astype(int)
y_test=y_test.astype(int)

# %%
from sklearn.preprocessing import StandardScaler
Sc=StandardScaler()
x_train_scaled=Sc.fit_transform(x_train)
x_test_scaled=Sc.fit_transform(x_test)

# %%
#LINEAR REGRESSION

from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test_scaled)

# %%
y_pred
# Out:
# array([11.16972737, 11.80614311, 10.65105873, 15.62415814, 22.46911474,
#        12.7292177 , 19.14571837, 10.6596263 ,  8.60331144,  6.92603718,
#        18.58656908, 17.87883379, 10.32460327, 14.2019067 , 15.92389947,
#         8.37923175, 12.6294257 , 15.25043946,  7.65130947, 15.0057478 ,
#         8.37379425, 18.36540693, 13.64880233, 19.71576823, 11.95631866,
#        10.81972861,  9.16534826, 16.84065319,  6.57594376,  9.69488098,
#        17.83021893,  7.6053863 , 15.411486  , 16.15513547, 16.44887602,
#         9.82746055, 13.04511841, 20.00939738, 10.91457769, 22.06085615,
#        10.68253977,  4.95017032, 20.03463636,  7.73602465, 20.43808777,
#        12.856072  , 15.39646413, 14.15964309, 17.0952865 , 11.48306363,
#        23.23441731,  7.21954251,  7.14507238, 16.11700732,  6.5136808 ,
#        15.23591449, 12.60418114, 19.60126198,  8.08040238, 10.76386524])

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8235389917995536

# %%
#ANALYSE THE PREDICTED SALES DATA

plt.scatter(y_test,y_pred,c='g')
